# %% [markdown]
# <a href="https://colab.research.google.com/github/harshit01422-pixel/Python-Lab/blob/main/9_1_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis
# ## Basics of Python
# ### Expt-1

# %%
print("I am Learning Python")
# Out:
# I am Learning Python

# %%
#Test code
print("I am at Symbiosis")

# %%
#16-1-26

# %%
print("Hi",end = ",") ; print("How are you ?")
# Out:
# Hi,How are you ?

# %%
print("Hello world",end="! ")
print("Im going to print in the same line")
# Out:
# Hello world! Im going to print in the same line

# %%
x=10
y=110.3
z="python"
a = True
c = +2j
print(type(x))
print(type(y))
print(type(z))
print(type(c))
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
name= input("Enter your name : ")
print("Hello",name)

# %%
#1 simple calclator
a = int(input("Enter the value of a : "))
b = int(input("Enter the value of b : "))
print("Addition of a and b is : ",a+b)
print("Subtraction of a and b is : ",a-b)
print("Multiplication of a and b is : ",a*b)
print("Division of a and b is : ",a/b)
print("Modulus of a and b is : ",a%b)
print("Exponent of a and b is : ",a**b)
print("Done")
# Out:
# Enter the value of a : 5
# Enter the value of b : 10
# Addition of a and b is :  15
# Subtraction of a and b is :  -5
# Multiplication of a and b is :  50
# Division of a and b is :  0.5
# Modulus of a and b is :  5
# Exponent of a and b is :  9765625
# Done

# %%
#2 Marks
sum = 0
avg = 0
for i in range(1,6):
    a = int(input("Enter student marks : "))
    sum+=a

print("Averge is ",sum/5)
print("sum is ",sum)
# Out:
# Enter student marks : 55
# Enter student marks : 65
# Enter student marks : 75
# Enter student marks : 85
# Enter student marks : 95
# Averge is  75.0
# sum is  375

# %%
#3 Find area of circle
r = float(input("Enter the radius of circle : "))
print("Area of the given circl is ",3.14*r*r)
# Out:
# Enter the radius of circle : 5
# Area of the given circl is  78.5

# %%
#4 Find area and perimeter of a rectangle
l = float(input("Enter the length of rectangle : "))
b = float(input("Enter the breadth of rectangle : "))
print("Area of the given rectangle is ",l*b)
print("Perimeter of the given rectangle is ",2*(l+b))
# Out:
# Enter the length of rectangle : 10
# Enter the breadth of rectangle : 12
# Area of the given rectangle is  120.0
# Perimeter of the given rectangle is  44.0
